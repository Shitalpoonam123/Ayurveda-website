# %% [markdown]
# # Data Analysis & visualization-using NumPy, pandas matplotlib, SciPy etc

# %% [markdown]
# # To understand the influence of the parents background, test preparation etc on students performance

# %%
# Importing Necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# reading csv file using pandas

df=pd.read_csv("exams.csv")

# %%
rows,columns=df.shape
print("Number of Records are:",rows)
print("Number of features are:",columns)
# Out:
# Number of Records are: 1000
# Number of features are: 8

# %%
#Getting the first five lines of the dataframe
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B                 high school      standard
# 1    male        group A            some high school  free/reduced
# 2    male        group D          associate's degree      standard
# 3    male        group C          associate's degree      standard
# 4    male        group B          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          65             76             76
# 1                    none          31             32             20
# 2                    none          91             90             86
# 3               completed          92             86             88
# 4                    none          60             55             50

# %%
df.info()
#docstring with literal block and unordered list
print(
"""
Getting the summary of the dataframe::

    -names of the columns
    -non null values count
    -data type of each column

""")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB
#
# Getting the summary of the dataframe::
#
#     -names of the columns
#     -non null values count
#     -data type of each column

# %%
#ordered list
"""
Mathematical summary of the dataframe values ::
    1.count
    2.mean
    3.std
    4.mean
    5.25% values
    6.50% values
    7.75% values
    8.max
"""
df.describe()
# Out:
#         math score  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     67.374000      70.193000      68.966000
# std      15.404591      15.170692      15.743529
# min      11.000000       9.000000       8.000000
# 25%      57.000000      59.000000      58.000000
# 50%      68.000000      71.000000      69.000000
# 75%      78.000000      81.000000      80.000000
# max     100.000000     100.000000     100.000000

# %%
df.isna().sum() #Checking for null values which is 0
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
a=df["gender"].value_counts()
b=df["race/ethnicity"].value_counts()
c=df["parental level of education"].value_counts()
d=df["lunch"].value_counts()
e=df["test preparation course"].value_counts()
print("=================================================")
print("Value counts of Gender:")
print(a)
print("=================================================")
print("Value counts of race:")
print(b)
print("=================================================")
print("Value counts of parent education:")
print(c)
print("=================================================")
print("Value counts of Lunch:")
print(d)
print("=================================================")
print("Value counts of Test preparation course:")
print(e)
print("=================================================")
# Out:
# =================================================
# Value counts of Gender:
# male      502
# female    498
# Name: gender, dtype: int64
# =================================================
# Value counts of race:
# group C    297
# group D    262
# group B    211
# group E    147
# group A     83
# Name: race/ethnicity, dtype: int64
# =================================================
# Value counts of parent education:
# some college          236
# high school           221
# some high school      181
# associate's degree    176
# bachelor's degree     118
# master's degree        68
# Name: parental level of education, dtype: int64
# =================================================
# Value counts of Lunch:
# standard        678
# free/reduced    322
# Name: lunch, dtype: int64
# =================================================
# Value counts of Test preparation course:
# none         643
# completed    357
# Name: test preparation course, dtype: int64
# =================================================

# %%
sns.countplot(df.gender)
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
sns.countplot(df["race/ethnicity"])
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='race/ethnicity', ylabel='count'>

# %%
sns.countplot(df["parental level of education"])
plt.subplots_adjust(hspace = 0.8)
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(df.lunch)
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='lunch', ylabel='count'>

# %%
sns.countplot(df["test preparation course"])
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='test preparation course', ylabel='count'>

# %%
sns.heatmap(df.corr(),annot=True)
plt.subplots_adjust(hspace = 0.8)

# %%
df['gender'].replace(['male', 'female'],
                        [0, 1], inplace=True)
df['race/ethnicity'].replace(['group A', 'group B','group C', 'group D', 'group E'],
                        [0, 1,2,3,4], inplace=True)
df['parental level of education'].replace(["some college","high school","some high school","associate's degree","bachelor's degree" ,"master's degree"],
                        [0, 1,2,3,4,5], inplace=True)
df['lunch'].replace(["standard","free/reduced"],
                        [0, 1], inplace=True)
df['test preparation course'].replace(['none', 'completed'],
                        [0, 1], inplace=True)

# %%
X=df.drop(columns=["math score","reading score","writing score"])
X.head()
# Out:
#    gender  race/ethnicity  parental level of education  lunch  \
# 0       1               1                            1      0
# 1       0               0                            2      1
# 2       0               3                            3      0
# 3       0               2                            3      0
# 4       0               1                            3      0
#
#    test preparation course
# 0                        0
# 1                        0
# 2                        0
# 3                        1
# 4                        0

# %%
fig, ax = plt.subplots()
sns.catplot(x="gender", y="math score", data=df,ax=ax)
sns.catplot(x="race/ethnicity", y="math score", data=df,ax=ax)
sns.catplot(x="parental level of education", y="math score", data=df,ax=ax)
sns.catplot(x="lunch", y="math score", data=df,ax=ax)
sns.catplot(x="test preparation course", y="math score", data=df,ax=ax)
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try stripplot
#   warnings.warn(msg, UserWarning)
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try stripplot
#   warnings.warn(msg, UserWarning)
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try stripplot
#   warnings.warn(msg, UserWarning)
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try stripplot
#   warnings.warn(msg, UserWarning)
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try stripplot
#   warnings.warn(msg, UserWarning)

# %%
g = sns.PairGrid(X)
g.map(sns.pointplot)

# %%
z=(df["math score"]+df["reading score"]+df["writing score"])//3

# %%
y=df["math score"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
...     X, y, test_size=0.33, random_state=42)

# %%
df.corr()
# Out:
#                                gender  race/ethnicity  \
# gender                       1.000000        0.006614
# race/ethnicity               0.006614        1.000000
# parental level of education  0.041594       -0.001222
# lunch                       -0.044328        0.006168
# test preparation course      0.055160        0.039534
# math score                  -0.133957        0.259049
# reading score                0.248221        0.184714
# writing score                0.311261        0.210058
#
#                              parental level of education     lunch  \
# gender                                          0.041594 -0.044328
# race/ethnicity                                 -0.001222  0.006168
# parental level of education                     1.000000 -0.012668
# lunch                                          -0.012668  1.000000
# test preparation course                         0.007366  0.000205
# math score                                      0.057702 -0.363552
# reading score                                   0.076869 -0.273844
# writing score                                   0.113155 -0.288893
#
#                              test preparation course  math score  \
# gender                                      0.055160   -0.133957
# race/ethnicity                              0.039534    0.259049
# parental level of education                 0.007366    0.057702
# lunch                                       0.000205   -0.363552
# test preparation course                     1.000000    0.131828
# math score                                  0.131828    1.000000
# reading score                               0.221903    0.837235
# writing score                               0.306152    0.814754
#
#                              reading score  writing score
# gender                            0.248221       0.311261
# race/ethnicity                    0.184714       0.210058
# parental level of education       0.076869       0.113155
# lunch                            -0.273844      -0.288893
# test preparation course           0.221903       0.306152
# math score                        0.837235       0.814754
# reading score                     1.000000       0.952486
# writing score                     0.952486       1.000000

# %%
df.hist()
plt.subplots_adjust(hspace = 0.8,wspace=2)

# %%
sns.distplot(df["reading score"])
sns.distplot(df["writing score"])
sns.distplot(df["math score"])
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='math score', ylabel='Density'>

# %%
sns.boxplot(df["gender"],df['math score'])
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='gender', ylabel='math score'>

# %%
sns.boxplot(df["race/ethnicity"],df['math score'])
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='race/ethnicity', ylabel='math score'>

# %%
sns.boxplot(df["parental level of education"],df['math score'])
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='parental level of education', ylabel='math score'>

# %% [markdown]
# **Conclusion:**
# <br> 1.For lunch and test preperation there is lots of difference between the count of each value
# <br> 2.There is very good correlation between writing and math score
# <br> 3.In rance/ethenticity order of better avg and min ,max is
# <br>      group E>D>C>B>A
# <br> 4.Male having little bit higher avg and min max than Female
# <br> 5.
# <br>
# <br>
